# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 실습해보기1
# ![image.png](attachment:6aebf84c-8265-49eb-b040-1d0252264662.png)

# %%
#Q1
lsDataFrame = pd.DataFrame([[-0.1, 0.0, -0.1, -0.2],
                            [1.8, 2.0, 1.6, 1.6],
                            [6.4, 6.8, 5.8, 5.9],
                            [12.3, 12.9, 11.5, 11.5],
                            [17.9, 18.5, 17.1, 17.1],
                            [22.2, 22.8, 21.6, 21.5]],
                             index=['1월', '2월', '3월', '4월', '5월', '6월'],
                            columns=['전북', '전주', '군산', '부안'])
print("Q1 :")
lsDataFrame
# Out:
# Q1 :
#       전북    전주    군산    부안
# 1월  -0.1   0.0  -0.1  -0.2
# 2월   1.8   2.0   1.6   1.6
# 3월   6.4   6.8   5.8   5.9
# 4월  12.3  12.9  11.5  11.5
# 5월  17.9  18.5  17.1  17.1
# 6월  22.2  22.8  21.6  21.5

# %%
#Q2
print(f"Q2 : 전주 3월 평균기온 = {lsDataFrame.iloc[2,1]}")
# Out:
# Q2 : 전주 3월 평균기온 = 6.8

# %%
#Q3
print(f"Q3 : 부안 4월 평균기온 = {lsDataFrame.iloc[3,3]}")
# Out:
# Q3 : 부안 4월 평균기온 = 11.5

# %%
#Q4
print(f"Q4 : 군산 1월 평균기온 = {lsDataFrame.loc['1월','군산']}")
# Out:
# Q4 : 군산 1월 평균기온 = -0.1

# %%
#Q5
print(f"Q5 : 전북 6월 평균기온 = {lsDataFrame.loc['6월','전북']}")
# Out:
# Q5 : 전북 6월 평균기온 = 22.2

# %% [markdown]
# # 실습해보기2
# ![image.png](attachment:a5998142-3a32-417d-af5d-4ccc916928a6.png)
# ![image.png](attachment:53355cfb-e49e-4698-b5d1-7c63a00587f1.png)

# %% [markdown]
# # 실습해보기 3
#
# ![image.png](attachment:1898db94-7d43-45ed-9b15-07a2f5e663d5.png)
# ![image.png](attachment:7509b65e-a86a-40de-8780-69f47c39463f.png)
